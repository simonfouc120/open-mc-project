# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import openmc
import os 
import json
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from pathlib import Path
import sys 
from PIL import Image
import numpy as np

CWD = Path.cwd().resolve()
project_root = Path.cwd().parents[4]
sys.path.append(str(project_root))

from parameters.parameters_paths import PATH_TO_CROSS_SECTIONS
from parameters.parameters_materials import (B4C_MATERIAL, HELIUM_MATERIAL, AIR_MATERIAL, LEAD_MATERIAL, STEEL_MATERIAL, CONCRETE_MATERIAL)
from src.utils.pre_processing.pre_processing import *
from src.utils.post_preocessing.post_processing import *
os.environ["OPENMC_CROSS_SECTIONS"] = PATH_TO_CROSS_SECTIONS

# %%
materials = openmc.Materials([B4C_MATERIAL, HELIUM_MATERIAL, AIR_MATERIAL, LEAD_MATERIAL, STEEL_MATERIAL, CONCRETE_MATERIAL])

# %%
CONTROL_RODS_DATA = {
    "rod_1": {"x": 0.0, "y": 0.0, "z": 0.0, "activity" : 4.0e10},
    "rod_2": {"x": 10.0, "y": 0.0, "z": 0.0, "activity" : 4.0e10},
    "rod_3": {"x": -10.0, "y": 0.0, "z": 0.0, "activity" : 4.0e10},
    "rod_4": {"x": 0.0, "y": 10.0, "z": 0.0, "activity" : 4.0e10},
    "rod_5": {"x": 0.0, "y": -10.0, "z": 0.0, "activity" : 4.0e10},
    "rod_6": {"x": 10.0, "y": 10.0, "z": 0.0, "activity" : 6.0e10},
    "rod_7": {"x": -10.0, "y": -10.0, "z": 0.0, "activity" : 6.0e10},
    "rod_8": {"x": 10.0, "y": -10.0, "z": 0.0, "activity" : 6.0e10},
    "rod_9": {"x": -10.0, "y": 10.0, "z": 0.0, "activity" : 6.0e10},
    "rod_10": {"x": 0.0, "y": 20.0, "z": 0.0, "activity" : 2.0e10},
    "rod_11": {"x": 20.0, "y": 0.0, "z": 0.0, "activity" : 2.0e10},
    "rod_12": {"x": -20.0, "y": 0.0, "z": 0.0, "activity" : 2.0e10},
    "rod_13": {"x": 0.0, "y": -20.0, "z": 0.0, "activity" : 2.0e10},
}


TOTAL_ACTIVITY = sum([rod["activity"] for rod in CONTROL_RODS_DATA.values()])

# Surfaces
steel_part_control_rods = openmc.Cylinder(r=4.0, surface_id=1)
helium_part_control_rods = openmc.Cylinder(r=3.3, surface_id=2)
b4c_part_control_rods = openmc.Cylinder(r=2.8, surface_id=3)

plane_top = openmc.ZPlane(z0=50.0, surface_id=300)
plane_bottom = openmc.ZPlane(z0=-50.0, surface_id=301)

detector = openmc.Sphere(x0=50., z0=25., r=15.0, surface_id=302)
# Place the detector at (x=50*cos(45°), y=50*sin(45°), z=0.0), which is 50 cm from (0,0) at a 45 degree angle
detector_x = 50.0 / np.sqrt(2)
detector_y = 50.0 / np.sqrt(2)
detector_45_deg = openmc.Sphere(x0=detector_x, y0=detector_y, z0=25.0, r=15.0, surface_id=303)
outer_boundary = openmc.Sphere(r=200.0, surface_id=304, boundary_type='vacuum')
# Out:
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=1.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=2.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=3.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=300.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=301.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=302.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=303.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=304.
#   warn(msg, IDWarning)

# %%
fig, ax = plt.subplots(figsize=(8, 8))
for i, (rod_name, rod_coords) in enumerate(CONTROL_RODS_DATA.items()):
    ax.scatter(rod_coords["x"], rod_coords["y"], s=750, label=f"{rod_name} (activity: {rod_coords['activity']:.1e})", edgecolor='black')
    ax.text(rod_coords["x"], rod_coords["y"], str(i+1), fontsize=20, ha='center', va='center')
ax.set_xlabel("X [cm]")
ax.set_ylabel("Y [cm]")
ax.set_title("Control Rods Coordinates")
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid()
plt.show()

# %%
# Define the other 8 control rods
control_rods = []
for i, rod_name in enumerate([k for k in CONTROL_RODS_DATA], start=2):
    coords = CONTROL_RODS_DATA[rod_name]
    steel_cyl = openmc.Cylinder(x0=coords["x"], y0=coords["y"], r=4.0, surface_id=10*i+1)
    helium_cyl = openmc.Cylinder(x0=coords["x"], y0=coords["y"], r=3.3, surface_id=10*i+2)
    b4c_cyl = openmc.Cylinder(x0=coords["x"], y0=coords["y"], r=2.8, surface_id=10*i+3)

    steel_cell = openmc.Cell(name=f"liner_steel_control_rod_{rod_name}")
    steel_cell.fill = STEEL_MATERIAL
    steel_cell.region = -steel_cyl & +helium_cyl & -plane_top & +plane_bottom

    helium_cell = openmc.Cell(name=f"helium_control_rod_{rod_name}")
    helium_cell.fill = HELIUM_MATERIAL
    helium_cell.region = -helium_cyl & +b4c_cyl & -plane_top & +plane_bottom

    b4c_cell = openmc.Cell(name=f"b4c_control_rod_{rod_name}")
    b4c_cell.fill = B4C_MATERIAL
    b4c_cell.region = -b4c_cyl & -plane_top & +plane_bottom

    control_rods.extend([steel_cell, helium_cell, b4c_cell])

# Add the other control rods to the universe
detector_cell = openmc.Cell(name="detector_cell")
detector_cell.fill = AIR_MATERIAL
detector_cell.region = -detector

detector_two_cell = openmc.Cell(name="detector_two_region")
detector_two_cell.fill = AIR_MATERIAL
detector_two_cell.region = -detector_45_deg

air_region = -outer_boundary & ~detector_cell.region & ~detector_two_cell.region
air_cell = openmc.Cell(name="air_cell", fill=AIR_MATERIAL, region=air_region)

universe = openmc.Universe(cells=[detector_cell, detector_two_cell, air_cell])
universe.add_cells(control_rods)

geometry = openmc.Geometry(universe)
# Out:
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=21.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=22.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=23.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=31.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=32.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=33.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=41.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=42.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=43.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=51.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=52.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=53.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=61.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=62.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=63.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=71.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=72.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=73.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=81.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=82.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=83.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=91.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=92.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=93.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=101.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=102.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=103.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=111.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=112.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=113.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=121.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=122.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=123.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=131.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=132.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=133.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=141.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=142.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=143.
#   warn(msg, IDWarning)

# %%
geometry.export_to_xml()
materials.export_to_xml()

# %%
plot_geometry(materials=materials, width=15, height=15, saving_figure=False, color_by="material")
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3-dev30
#      Commit Hash | cb95c784b755719d9e5897bb550611eb0a8e542a
#        Date/Time | 2025-07-28 13:00:16
#
#  Reading settings XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#
#  =======================>     PLOTTING SUMMARY     <========================
#
# Plot ID: 48
# Plot file: plot_openmc_xy.png
# Universe depth: -1
# Plot Type: Slice
# Origin: 0 0 0
# Width:   15   15
# Coloring: Materials
# Basis: XY
# Pixels: 600 600
#
#  Processing plot 48: plot_openmc_xy.png...

# %%
plot_geometry(materials=materials, width=50, height=50, saving_figure=False, color_by="material")
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3-dev30
#      Commit Hash | cb95c784b755719d9e5897bb550611eb0a8e542a
#        Date/Time | 2025-07-28 13:00:16
#
#  Reading settings XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#
#  =======================>     PLOTTING SUMMARY     <========================
#
# Plot ID: 49
# Plot file: plot_openmc_xy.png
# Universe depth: -1
# Plot Type: Slice
# Origin: 0 0 0
# Width:   50   50
# Coloring: Materials
# Basis: XY
# Pixels: 600 600
#
#  Processing plot 49: plot_openmc_xy.png...

# %%
plot_geometry(materials=materials, width=175, height=175, saving_figure=False, color_by="cell", origin=(0, 0, 25.0))
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3-dev30
#      Commit Hash | cb95c784b755719d9e5897bb550611eb0a8e542a
#        Date/Time | 2025-07-28 13:00:16
#
#  Reading settings XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  WARNING: Could not find cell 1 specified in plot 50
#  WARNING: Could not find cell 2 specified in plot 50
#  WARNING: Could not find cell 9 specified in plot 50
#  WARNING: Could not find cell 10 specified in plot 50
#  WARNING: Could not find cell 18 specified in plot 50
#  WARNING: Could not find cell 20 specified in plot 50
#
#  =======================>     PLOTTING SUMMARY     <========================
#
# Plot ID: 50
# Plot file: plot_openmc_xy.png
# Universe depth: -1
# Plot Type: Slice
# Origin: 0 0 25
# Width:  175  175
# Coloring: Cells
# Basis: XY
# Pixels: 600 600
#
#  Processing plot 50: plot_openmc_xy.png...

# %%
plot_geometry(materials=materials, width=120, height=120, plane="xz", saving_figure=False)
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3-dev30
#      Commit Hash | cb95c784b755719d9e5897bb550611eb0a8e542a
#        Date/Time | 2025-07-28 13:00:16
#
#  Reading settings XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#
#  =======================>     PLOTTING SUMMARY     <========================
#
# Plot ID: 51
# Plot file: plot_openmc_xz.png
# Universe depth: -1
# Plot Type: Slice
# Origin: 0 0 0
# Width:  120  120
# Coloring: Materials
# Basis: XZ
# Pixels: 600 600
#
#  Processing plot 51: plot_openmc_xz.png...

# %%
plot_geometry(materials=materials, width=100, height=100, plane="yz", saving_figure=False)
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3-dev30
#      Commit Hash | cb95c784b755719d9e5897bb550611eb0a8e542a
#        Date/Time | 2025-07-28 13:00:16
#
#  Reading settings XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#
#  =======================>     PLOTTING SUMMARY     <========================
#
# Plot ID: 52
# Plot file: plot_openmc_yz.png
# Universe depth: -1
# Plot Type: Slice
# Origin: 0 0 0
# Width:  100  100
# Coloring: Materials
# Basis: YZ
# Pixels: 600 600
#
#  Processing plot 52: plot_openmc_yz.png...

# %%
sources = []
z_bounds = [-50.0, -40.0, -30.0, -20.0, -10.0, 0.0, 10.0, 20.0, 30.0, 40.0, 50.0]
probs = [0.1, 0.12, 0.14, 0.156, 0.16, 0.23, 0.25, 0.45, 0.3, 0.1]
total = sum(probs)
probs = [p / total for p in probs]

z_dist = openmc.stats.Tabular(z_bounds, probs, interpolation='histogram')

r = openmc.stats.PowerLaw(3.3, 4.0, 1.0) # from 3.3 to 4.0 cm
phi = openmc.stats.Uniform(0, 2*np.pi)
z = z_dist
for coords in CONTROL_RODS_DATA.values():
    x = coords["x"]
    y = coords["y"]
    source = openmc.IndependentSource()
    source.space = openmc.stats.CylindricalIndependent(r=r, phi=phi, z=z, origin=(x, y, 0))
    source.angle = openmc.stats.Isotropic()
    source.energy = openmc.stats.Discrete([1.1732e6,1.3325e6], [0.5, 0.5])
    source.strength = coords["activity"]  # Activity in Bq
    source.particle = "photon"
    sources.append(source)

# %%
z_centers = [(z_bounds[i] + z_bounds[i+1]) / 2 for i in range(len(z_bounds) - 1)]
plt.bar(z_centers, probs, width=10, align='center', alpha=0.7, color='none', edgecolor='black')
plt.xlabel('Z [cm]')
plt.ylabel('Probability')
plt.title('Axial Distribution')
plt.show()

# %%
tallies = openmc.Tallies([])
mesh_tally_xy = mesh_tally_plane(plane="xy", particule_type="photon", name_mesh_tally="flux_mesh_xy", thickness=4.0, coord_value=0.0)
tallies.append(mesh_tally_xy)

mesh_tally_yz = mesh_tally_plane(plane="xz", particule_type="photon", name_mesh_tally="flux_mesh_yz")
tallies.append(mesh_tally_yz)

for z_value in np.arange(-60, 61, 5):
    mesh_tally_xy_var_z = mesh_tally_plane(plane="xy", particule_type="photon", name_mesh_tally=f"flux_mesh_xy_z_{z_value}", 
                                     thickness=5.0, coord_value=z_value, upper_right=(30.0, 30.0), lower_left=(-30.0, -30.0))
    tallies.append(mesh_tally_xy_var_z)

# %%
tally_dose_photon = openmc.Tally(name="dose_tally_sphere_photons")
particule_type = 'photon' 
energy_bins, dose_coeffs = openmc.data.dose_coefficients(particle="photon", geometry="ISO")
energy_function_filter = openmc.EnergyFunctionFilter(energy_bins, dose_coeffs, interpolation='cubic')
cell_filter = openmc.CellFilter(detector_cell)
particle_filter = openmc.ParticleFilter([particule_type])
tally_dose_photon.filters = [cell_filter, particle_filter, energy_function_filter]
tally_dose_photon.scores = ['flux']
tallies.append(tally_dose_photon)

# %%
tally_dose_photon_45_deg = openmc.Tally(name="dose_tally_sphere_photons_45_deg")
particule_type = 'photon' 
cell_filter = openmc.CellFilter(detector_two_cell)
particle_filter = openmc.ParticleFilter([particule_type])
tally_dose_photon_45_deg.filters = [cell_filter, particle_filter, energy_function_filter]
tally_dose_photon_45_deg.scores = ['flux']
tallies.append(tally_dose_photon_45_deg)

# %%
# Configuration de la simulation
settings = openmc.Settings()
batches_number = 50
settings.batches = batches_number
settings.particles = 10**6
settings.source = sources
settings.uniform_source_sampling = True
settings.photon_transport = True
settings.run_mode = "fixed source"
settings.verbose = True

# %%
settings.export_to_xml()
tallies.export_to_xml()
# Out:
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=474.
#   warn(msg, IDWarning)

# %%
remove_previous_results(batches_number)
openmc.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3-dev30
#      Commit Hash | cb95c784b755719d9e5897bb550611eb0a8e542a
#        Date/Time | 2025-07-28 13:00:18
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading N14 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/N14.h5
#  Reading N from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/N.h5
#  Reading N15 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/N15.h5
#  Reading O16 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/O16.h5
#  Reading O from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/O.h5
#  Reading O17 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/O17.h5
#  Reading O18 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/O18.h5
#  Reading Ar36 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/Ar.h5
#  Reading Ar38 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Ar38.h5
#  Reading Ar40 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Ar40.h5
#  Reading He3 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/He3.h5
#  Reading He from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/He.h5
#  Reading He4 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/He4.h5
#  Reading Si28 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Si28.h5
#  Reading Si from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/Si.h5
#  Reading Si29 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Si29.h5
#  Reading Si30 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Si30.h5
#  Reading Ca40 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Ca40.h5
#  Reading Ca from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/Ca.h5
#  Reading Ca42 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Ca42.h5
#  Reading Ca43 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Ca43.h5
#  Reading Ca44 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Ca44.h5
#  Reading Ca46 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Ca46.h5
#  Reading Ca48 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Ca48.h5
#  Reading Al27 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Al27.h5
#  Reading Al from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/Al.h5
#  Reading Fe54 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Fe54.h5
#  Reading Fe from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/Fe.h5
#  Reading Fe56 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Fe56.h5
#  Reading Fe57 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Fe57.h5
#  Reading Fe58 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Fe58.h5
#  Reading Mg24 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Mg24.h5
#  Reading Mg from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/Mg.h5
#  Reading Mg25 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Mg25.h5
#  Reading Mg26 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Mg26.h5
#  Reading Na23 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Na23.h5
#  Reading Na from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/Na.h5
#  Reading K39 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/K39.h5
#  Reading K from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/K.h5
#  Reading K40 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/K40.h5
#  Reading K41 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/K41.h5
#  Reading Pb204 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Pb204.h5
#  Reading Pb from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/Pb.h5
#  Reading Pb206 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Pb206.h5
#  Reading Pb207 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Pb207.h5
#  Reading Pb208 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Pb208.h5
#  Reading B10 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/B10.h5
#  Reading B from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/B.h5
#  Reading B11 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/B11.h5
#  Reading C12 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/C12.h5
#  Reading C from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/C.h5
#  Reading C13 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/C13.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for N15
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Simulating batch 6
#  Simulating batch 7
#  Simulating batch 8
#  Simulating batch 9
#  Simulating batch 10
#  Simulating batch 11
#  Simulating batch 12
#  Simulating batch 13
#  Simulating batch 14
#  Simulating batch 15
#  Simulating batch 16
#  Simulating batch 17
#  Simulating batch 18
#  Simulating batch 19
#  Simulating batch 20
#  Simulating batch 21
#  Simulating batch 22
#  Simulating batch 23
#  Simulating batch 24
#  Simulating batch 25
#  Simulating batch 26
#  Simulating batch 27
#  Simulating batch 28
#  Simulating batch 29
#  Simulating batch 30
#  Simulating batch 31
#  Simulating batch 32
#  Simulating batch 33
#  Simulating batch 34
#  Simulating batch 35
#  Simulating batch 36
#  Simulating batch 37
#  Simulating batch 38
#  Simulating batch 39
#  Simulating batch 40
#  Simulating batch 41
#  Simulating batch 42
#  Simulating batch 43
#  Simulating batch 44
#  Simulating batch 45
#  Simulating batch 46
#  Simulating batch 47
#  Simulating batch 48
#  Simulating batch 49
#  Simulating batch 50
#  Creating state point statepoint.50.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 2.0754e+00 seconds
#    Reading cross sections          = 2.0646e+00 seconds
#  Total time in simulation          = 1.2651e+03 seconds
#    Time in transport only          = 1.2648e+03 seconds
#    Time in active batches          = 1.2651e+03 seconds
#    Time accumulating tallies       = 2.2336e-01 seconds
#    Time writing statepoints        = 8.0333e-02 seconds
#  Total time for finalization       = 2.7070e+00 seconds
#  Total time elapsed                = 1.2699e+03 seconds
#  Calculation Rate (active)         = 39521.4 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.94927 +/- 0.00004

# %%
sp = openmc.StatePoint(f"statepoint.{batches_number}.h5")

# %%
load_mesh_tally(statepoint_file=sp, cwd = CWD, name_mesh_tally="flux_mesh_xy", particule_type="photon",
                plane = "xy", upper_right=(50, 50), lower_left=(-50, -50),
                zoom_x=(-50, 50), zoom_y=(-50, 50), saving_figure=False, plot_error=True)

# %%
load_mesh_tally(statepoint_file=sp, cwd = CWD, name_mesh_tally="flux_mesh_yz", particule_type="photon",
                plane = "xz", upper_right=(50, 50), lower_left=(-50, -50),
                zoom_x=(-50, 50), zoom_y=(-50, 50), saving_figure=False, plot_error=True)

# %% [markdown]
# Load every mesh tally plane and calculate the mean of the flux

# %%
mean_flux = []
mean_flux_error = []
z_values = np.arange(-60, 61, 5)
for z_val in z_values:
    tally_name = f"flux_mesh_xy_z_{z_val}"
    mesh_tally = sp.get_tally(name=tally_name)
    flux_data = mesh_tally.mean.reshape((400, 400))
    mean_flux.append(np.mean(flux_data))
    flux_error = mesh_tally.std_dev.reshape((400, 400))
    flux_error = flux_error / flux_data
    mean_flux_error.append(np.mean(flux_error))

mean_flux = np.array(mean_flux)
mean_flux_error = np.array(mean_flux_error)

# %% [markdown]
# Compare axial disitribution of the control rods with the flux on several planes of altimetry

# %%
fig, ax1 = plt.subplots(figsize=(8, 6))
ax1.set_xlabel('Z [cm]')
ax1.set_ylabel('Flux [particule/s]', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.grid()
ax1.errorbar(z_values, mean_flux, yerr=mean_flux * mean_flux_error, fmt='-o', color='tab:blue', label='Mean Flux (± rel. error)')

ax2 = ax1.twinx()
ax2.bar(z_centers, probs, width=10, align='center', alpha=0.9, color='none', edgecolor='red')
ax2.set_ylabel('Probability', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')

fig.suptitle('Mean Flux and Axial Distribution vs Z')
fig.tight_layout()
plt.show()

# %% [markdown]
# Débits de dose à proximité des barres de commande

# %%
dose_photon_result = sp.get_tally(name="dose_tally_sphere_photons")
dose_photon_45_deg_result = sp.get_tally(name="dose_tally_sphere_photons_45_deg")

dose_photon = dose_photon_result.mean.flatten()
dose_photon_std = dose_photon_result.std_dev.flatten()
dose_photon_45 = dose_photon_45_deg_result.mean.flatten()
dose_photon_45_std = dose_photon_45_deg_result.std_dev.flatten()

volume_cell_sphere_calculation = Volume_cell(detector_cell, surface_type=detector_cell.region.surface.type)

dose_results = {
    "detector": {
        "dose": dose_photon * (1e-6 * 3600) / volume_cell_sphere_calculation.get_volume(),
        "std": dose_photon_std * (1e-6 * 3600) / volume_cell_sphere_calculation.get_volume()
    },
    "detector_45_deg": {
        "dose": dose_photon_45 * (1e-6 * 3600) / volume_cell_sphere_calculation.get_volume(),
        "std": dose_photon_45_std * (1e-6 * 3600) / volume_cell_sphere_calculation.get_volume()
    }
}

print(f"Dose at detector: {dose_results['detector']['dose'][0]:.2e} ± {dose_results['detector']['std'][0]:.2e} µSv/h")
print(f"Relative error: {dose_results['detector']['std'][0] / dose_results['detector']['dose'][0]:.2%}")
print(f"Dose at detector 45°: {dose_results['detector_45_deg']['dose'][0]:.2e} ± {dose_results['detector_45_deg']['std'][0]:.2e} µSv/h")
print(f"Relative error: {dose_results['detector_45_deg']['std'][0] / dose_results['detector_45_deg']['dose'][0]:.2%}")

print(f"Dose at detector: {dose_results['detector']['dose'][0] * 1e-3:.2E} ± {dose_results['detector']['std'][0] * 1e-3:.2E} mSv/h")
print(f"Dose at detector 45°: {dose_results['detector_45_deg']['dose'][0] * 1e-3:.2E} ± {dose_results['detector_45_deg']['std'][0] * 1e-3:.2E} mSv/h")
# Out:
# Dose at detector: 1.74e+05 ± 2.04e+02 µSv/h
# Relative error: 0.12%
# Dose at detector 45°: 1.74e+05 ± 1.87e+02 µSv/h
# Relative error: 0.11%
# Dose at detector: 1.74E+02 ± 2.04E-01 mSv/h
# Dose at detector 45°: 1.74E+02 ± 1.87E-01 mSv/h
