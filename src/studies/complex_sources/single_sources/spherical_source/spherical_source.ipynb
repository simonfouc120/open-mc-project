# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import openmc
import os 
import json
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from pathlib import Path
import sys 
from PIL import Image
import numpy as np

CWD = Path.cwd().resolve()
project_root = Path.cwd().parents[4]
sys.path.append(str(project_root))

from parameters.parameters_paths import PATH_TO_CROSS_SECTIONS
from parameters.parameters_materials import (FUEL_MATERIAL, HELIUM_MATERIAL, AIR_MATERIAL, 
                                             CONCRETE_MATERIAL, CS137_MATERIAL, CDTE_MATERIAL)
from src.utils.pre_processing.pre_processing import *
from src.utils.post_preocessing.post_processing import *
os.environ["OPENMC_CROSS_SECTIONS"] = PATH_TO_CROSS_SECTIONS

# %%
materials = openmc.Materials([CS137_MATERIAL, CDTE_MATERIAL, AIR_MATERIAL, CONCRETE_MATERIAL])

# %%
# Surfaces
sphere = openmc.Sphere(r=10.0, surface_id=1)
detector = openmc.Sphere(x0=30., r=10.0, surface_id=2)
outer_boundary = openmc.Sphere(r=200.0, surface_id=3, boundary_type='vacuum')

# Create concrete wall using parallelepiped
wall_region = parallelepiped(-40, -20, -50, 50, -50, 50, surface_id_start=10) # type: ignore
wall_cell = openmc.Cell(name="concrete_wall", fill=CONCRETE_MATERIAL, region=wall_region)
# Out:
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=1.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=2.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=3.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=10.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=11.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=12.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=13.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=14.
#   warn(msg, IDWarning)
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=15.
#   warn(msg, IDWarning)

# %%
# Cells
source_cell = openmc.Cell(name="source_cell")
source_cell.fill = CS137_MATERIAL
source_cell.region = -sphere

detector_cell = openmc.Cell(name="detector_cell")
detector_cell.fill = CDTE_MATERIAL
detector_cell.region = -detector

# Air cell (everything else inside the outer boundary, minus source, detector, and wall)
outer_boundary_cell = -outer_boundary
void_region = outer_boundary_cell & ~source_cell.region & ~detector_cell.region & ~wall_region
void_cell = openmc.Cell(name="air_cell", fill=AIR_MATERIAL, region=void_region)

universe = openmc.Universe(cells=[source_cell, detector_cell, wall_cell, void_cell])
geometry = openmc.Geometry(universe)

# %%
geometry.export_to_xml()
materials.export_to_xml()

# %%
plot_geometry(materials=materials, width=100, height=100, saving_figure=False)
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3-dev30
#      Commit Hash | cb95c784b755719d9e5897bb550611eb0a8e542a
#        Date/Time | 2025-07-24 11:11:23
#
#  Reading settings XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#
#  =======================>     PLOTTING SUMMARY     <========================
#
# Plot ID: 3
# Plot file: plot_openmc_xy.png
# Universe depth: -1
# Plot Type: Slice
# Origin: 0 0 0
# Width:  100  100
# Coloring: Materials
# Basis: XY
# Pixels: 600 600
#
#  Processing plot 3: plot_openmc_xy.png...

# %%
plot_geometry(materials=materials, width=100, height=100, plane="yz", saving_figure=False)
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3-dev30
#      Commit Hash | cb95c784b755719d9e5897bb550611eb0a8e542a
#        Date/Time | 2025-07-24 11:11:23
#
#  Reading settings XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#
#  =======================>     PLOTTING SUMMARY     <========================
#
# Plot ID: 4
# Plot file: plot_openmc_yz.png
# Universe depth: -1
# Plot Type: Slice
# Origin: 0 0 0
# Width:  100  100
# Coloring: Materials
# Basis: YZ
# Pixels: 600 600
#
#  Processing plot 4: plot_openmc_yz.png...

# %%
src = openmc.Source()
src.space = openmc.stats.Box(
    (-10, -10, -2.5), (10, 10, 2.5), only_fissionable=False)
src.angle = openmc.stats.Isotropic()
src.energy = openmc.stats.Discrete([661_700], [1.0])
src.particle = "photon"
# Out:
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/source.py:658: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn("This class is deprecated in favor of 'IndependentSource'", FutureWarning)

# %%
radius = openmc.stats.Discrete([3], [1])
r = openmc.stats.Uniform(0.0, 0.999999*3.0)  # Use a float for the upper bound
phi = openmc.stats.Uniform(0, 2*np.pi)
theta = openmc.stats.Uniform(-1, 1)
source = openmc.IndependentSource()
source.space = openmc.stats.SphericalIndependent(r, phi, theta)
source.angle = openmc.stats.Isotropic()
source.energy = openmc.stats.Discrete([661_700], [1.0])
source.particle = "photon"

# %%
source = openmc.Source()
source.space = openmc.stats.spherical_uniform(r_inner=0, r_outer=10, origin=(0, 0, 0))  # Reference direction for isotropic sampling
source.angle = openmc.stats.Isotropic()
source.energy = openmc.stats.Discrete([661_700], [1.0])
source.particle = "photon"

# %%
tallies = openmc.Tallies([])
mesh_tally_xy = mesh_tally_plane(plane="xy", particule_type="photon", name_mesh_tally="flux_mesh_xy")
tallies.append(mesh_tally_xy)

mesh_tally_yz = mesh_tally_plane(plane="yz", particule_type="photon", name_mesh_tally="flux_mesh_yz")
tallies.append(mesh_tally_yz)

# %%
# Configuration de la simulation
settings = openmc.Settings()
batches_number = 30
settings.batches = batches_number
settings.particles = 10**6
settings.source = source
# settings.uniform_source_sampling = True

settings.photon_transport = True
settings.run_mode = "fixed source"
settings.verbose = True

# %%
materials.export_to_xml()
geometry.export_to_xml()
settings.export_to_xml()
tallies.export_to_xml()
# Out:
# /Users/simonfoucambert/miniconda3/envs/openmc-arm/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=6.
#   warn(msg, IDWarning)

# %%
remove_previous_results(batches_number)
openmc.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3-dev30
#      Commit Hash | cb95c784b755719d9e5897bb550611eb0a8e542a
#        Date/Time | 2025-07-24 11:11:23
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading N14 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/N14.h5
#  Reading N from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/N.h5
#  Reading N15 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/N15.h5
#  Reading O16 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/O16.h5
#  Reading O from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/O.h5
#  Reading O17 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/O17.h5
#  Reading O18 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/O18.h5
#  Reading Ar36 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/Ar.h5
#  Reading Ar38 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Ar38.h5
#  Reading Ar40 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Ar40.h5
#  Reading Cs137 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Cs137.h5
#  Reading Cs from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/Cs.h5
#  Reading Cd106 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/Cd.h5
#  Reading Cd108 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Cd108.h5
#  Reading Cd110 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Cd110.h5
#  Reading Cd111 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Cd111.h5
#  Reading Cd112 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Cd112.h5
#  Reading Cd113 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Cd113.h5
#  Reading Cd114 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Cd114.h5
#  Reading Cd116 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Cd116.h5
#  Reading Te120 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Te120.h5
#  Reading Te from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/Te.h5
#  Reading Te122 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Te122.h5
#  Reading Te123 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Te123.h5
#  Reading Te124 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Te124.h5
#  Reading Te125 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Te125.h5
#  Reading Te126 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Te126.h5
#  Reading Te128 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Te128.h5
#  Reading Te130 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Te130.h5
#  Reading Si28 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Si28.h5
#  Reading Si from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/Si.h5
#  Reading Si29 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Si29.h5
#  Reading Si30 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Si30.h5
#  Reading Ca40 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Ca40.h5
#  Reading Ca from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/Ca.h5
#  Reading Ca42 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Ca42.h5
#  Reading Ca43 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Ca43.h5
#  Reading Ca44 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Ca44.h5
#  Reading Ca46 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Ca46.h5
#  Reading Ca48 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Ca48.h5
#  Reading Al27 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Al27.h5
#  Reading Al from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/Al.h5
#  Reading Fe54 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Fe54.h5
#  Reading Fe from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/Fe.h5
#  Reading Fe56 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Fe56.h5
#  Reading Fe57 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Fe57.h5
#  Reading Fe58 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Fe58.h5
#  Reading Mg24 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Mg24.h5
#  Reading Mg from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/Mg.h5
#  Reading Mg25 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Mg25.h5
#  Reading Mg26 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Mg26.h5
#  Reading Na23 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/Na23.h5
#  Reading Na from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/Na.h5
#  Reading K39 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/K39.h5
#  Reading K from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/pho
#  ton/K.h5
#  Reading K40 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/K40.h5
#  Reading K41 from
#  /Users/simonfoucambert/Documents/projects/open-mc-project/lib/cross_sections/neu
#  tron/K41.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for N15
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Simulating batch 6
#  Simulating batch 7
#  Simulating batch 8
#  Simulating batch 9
#  Simulating batch 10
#  Simulating batch 11
#  Simulating batch 12
#  Simulating batch 13
#  Simulating batch 14
#  Simulating batch 15
#  Simulating batch 16
#  Simulating batch 17
#  Simulating batch 18
#  Simulating batch 19
#  Simulating batch 20
#  Simulating batch 21
#  Simulating batch 22
#  Simulating batch 23
#  Simulating batch 24
#  Simulating batch 25
#  Simulating batch 26
#  Simulating batch 27
#  Simulating batch 28
#  Simulating batch 29
#  Simulating batch 30
#  Creating state point statepoint.30.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.4941e+00 seconds
#    Reading cross sections          = 1.4889e+00 seconds
#  Total time in simulation          = 2.3025e+02 seconds
#    Time in transport only          = 2.3023e+02 seconds
#    Time in active batches          = 2.3025e+02 seconds
#    Time accumulating tallies       = 1.0068e-02 seconds
#    Time writing statepoints        = 8.3996e-03 seconds
#  Total time for finalization       = 2.1105e-01 seconds
#  Total time elapsed                = 2.3196e+02 seconds
#  Calculation Rate (active)         = 130295 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.30582 +/- 0.00009

# %%
sp = openmc.StatePoint(f"statepoint.{batches_number}.h5")

# %%
load_mesh_tally(statepoint_file=sp, cwd = CWD, name_mesh_tally="flux_mesh_xy", particule_type="photon",
                plane = "xy", upper_right=(50, 50), lower_left=(-50, -50),
                zoom_x=(-50, 50), zoom_y=(-50, 50), saving_figure=False, plot_error=True)

# %%
load_mesh_tally(statepoint_file=sp, cwd = CWD, name_mesh_tally="flux_mesh_yz", particule_type="photon",
                plane = "yz", upper_right=(50, 50), lower_left=(-50, -50),
                zoom_x=(-50, 50), zoom_y=(-50, 50), saving_figure=False, plot_error=True)
